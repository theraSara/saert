# %% [markdown]
# Do sparse autoencoder features from GPT-2-small residual-stream activations predict human reading times beyond lexical controls and GPT-2 surprisal?

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

PROJECT_ROOT = Path('/Users/vanilla/Documents/PALM/saert')
DATASET_ORDER = ['Provo', 'Natural Stories']

COLORS = {
    'Provo': '#0072B2',           
    'Natural Stories': '#D55E00',
}

HEATMAP_CMAP = 'YlGn'

provo = pd.read_csv(PROJECT_ROOT / 'results/regression/provo_sae_regression.csv')
ns = pd.read_csv(PROJECT_ROOT / 'results/regression/natural_stories_sae_regression.csv')
results = pd.concat([provo, ns], ignore_index=True)
results['dataset'] = results['corpus'].map({'provo': 'Provo', 'natural_stories': 'Natural Stories'})

GLOBAL_HEAT_RANGES = {
    'Controls R²': (0, float(results['heldout_r2_controls'].max())),
    'Controls + surprisal R²': (0, float(results['heldout_r2_controls_surprisal'].max())),
    'Combined R²': (0, float(results['heldout_r2_combined'].max())),
    'ΔR² surprisal': (0, float(results['heldout_delta_r2_surprisal'].max())),
    'ΔR² SAE': (0, float(results['heldout_delta_r2_sae_over_surprisal'].max())),
    'Stable features': (0, float(results['n_sae_features_selected_stable_60pct'].max())),
}

pd.set_option('display.max_columns', 80)
pd.set_option('display.width', 140)


def show_heat_table(df, heat_cols, caption=None, precision=4, ranges=None):
    """Display a numeric table with consistent colorblind-safe heatmap shading."""
    ranges = ranges or {}
    styler = df.style.format(precision=precision)
    for col in heat_cols:
        if col in df.columns:
            vmin, vmax = ranges.get(col, (None, None))
            styler = styler.background_gradient(cmap=HEATMAP_CMAP, subset=[col], vmin=vmin, vmax=vmax)
    styler = (
        styler
        .set_properties(**{'text-align': 'center'})
        .set_table_styles([
            {'selector': 'th', 'props': [('text-align', 'center'), ('font-weight', '600')]},
            {'selector': 'caption', 'props': [('caption-side', 'top'), ('font-weight', '600'), ('font-size', '14px')]},
        ])
    )
    if caption:
        styler = styler.set_caption(caption)
    display(styler)

plt.rcParams.update({
    'font.size': 11,
    'axes.spines.top': False,
    'axes.spines.right': False,
})

# %%
best_rows = []
for dataset, df in results.groupby('dataset'):
    best = df.loc[df['heldout_delta_r2_sae_over_surprisal'].idxmax()]
    best_rows.append({
        'Dataset': dataset,
        'Words': int(best['n_words']),
        'Best layer': int(best['layer']),
        'Controls R²': best['heldout_r2_controls'],
        'Controls + surprisal R²': best['heldout_r2_controls_surprisal'],
        'Combined R²': best['heldout_r2_combined'],
        'ΔR² surprisal': best['heldout_delta_r2_surprisal'],
        'ΔR² SAE': best['heldout_delta_r2_sae_over_surprisal'],
        'SAE CI low': best['delta_sae_over_surprisal_ci_low'],
        'SAE CI high': best['delta_sae_over_surprisal_ci_high'],
        'Stable features': int(best['n_sae_features_selected_stable_60pct']),
    })

best_summary = pd.DataFrame(best_rows)
best_summary['Dataset'] = pd.Categorical(best_summary['Dataset'], categories=DATASET_ORDER, ordered=True)
best_summary = best_summary.sort_values('Dataset').reset_index(drop=True)

show_heat_table(
    best_summary,
    heat_cols=['Controls R²', 'Controls + surprisal R²', 'Combined R²', 'ΔR² surprisal', 'ΔR² SAE', 'Stable features'],
    ranges=GLOBAL_HEAT_RANGES,
    caption='Best SAE layer per dataset. Darker cells indicate larger values on a shared color scale.',
)
# Out:
# <style type="text/css">
# #T_93c54 th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_93c54 caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_93c54_row0_col0, #T_93c54_row0_col1, #T_93c54_row0_col2, #T_93c54_row0_col8, #T_93c54_row0_col9, #T_93c54_row1_col0, #T_93c54_row1_col1, #T_93c54_row1_col2, #T_93c54_row1_col8, #T_93c54_row1_col9 {
#   text-align: center;
# }
# #T_93c54_row0_col3, #T_93c54_row1_col4, #T_93c54_row1_col5, #T_93c54_row1_col6, #T_93c54_row1_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_93c54_row0_col4 {
#   background-color: #005f34;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_93c54_row0_col5 {
#   background-color: #278946;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_93c54_row0_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
#   text-align: center;
# }
# #T_93c54_row0_col7 {
#   background-color: #89ce80;
#   color: #000000;
#   text-align: center;
# }
# #T_93c54_row0_col10 {
#   background-color: #6dc073;
#   color: #000000;
#   text-align: center;
# }
# #T_93c54_row1_col3 {
#   background-color: #005d33;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_93c54_row1_col10 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_93c54">
#   <caption>Best SAE layer per dataset. Darker cells indicate larger values on a shared color scale.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93c54_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_93c54_level0_col1" class="col_heading level0 col1" >Words</th>
#       <th id="T_93c54_level0_col2" class="col_heading level0 col2" >Best layer</th>
#       <th id="T_93c54_level0_col3" class="col_heading level0 col3" >Controls R²</th>
#       <th id="T_93c54_level0_col4" class="col_heading level0 col4" >Controls + surprisal R²</th>
#       <th id="T_93c54_level0_col5" class="col_heading level0 col5" >Combined R²</th>
#       <th id="T_93c54_level0_col6" class="col_heading level0 col6" >ΔR² surprisal</th>
#       <th id="T_93c54_level0_col7" class="col_heading level0 col7" >ΔR² SAE</th>
#       <th id="T_93c54_level0_col8" class="col_heading level0 col8" >SAE CI low</th>
#       <th id="T_93c54_level0_col9" class="col_heading level0 col9" >SAE CI high</th>
#       <th id="T_93c54_level0_col10" class="col_heading level0 col10" >Stable features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93c54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93c54_row0_col0" class="data row0 col0" >Provo</td>
#       <td id="T_93c54_row0_col1" class="data row0 col1" >2630</td>
#       <td id="T_93c54_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_93c54_row0_col3" class="data row0 col3" >0.1457</td>
#       <td id="T_93c54_row0_col4" class="data row0 col4" >0.1530</td>
#       <td id="T_93c54_row0_col5" class="data row0 col5" >0.2021</td>
#       <td id="T_93c54_row0_col6" class="data row0 col6" >0.0073</td>
#       <td id="T_93c54_row0_col7" class="data row0 col7" >0.0491</td>
#       <td id="T_93c54_row0_col8" class="data row0 col8" >0.0334</td>
#       <td id="T_93c54_row0_col9" class="data row0 col9" >0.0633</td>
#       <td id="T_93c54_row0_col10" class="data row0 col10" >58</td>
#     </tr>
#     <tr>
#       <th id="T_93c54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93c54_row1_col0" class="data row1 col0" >Natural Stories</td>
#       <td id="T_93c54_row1_col1" class="data row1 col1" >10246</td>
#       <td id="T_93c54_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_93c54_row1_col3" class="data row1 col3" >0.1331</td>
#       <td id="T_93c54_row1_col4" class="data row1 col4" >0.1692</td>
#       <td id="T_93c54_row1_col5" class="data row1 col5" >0.2759</td>
#       <td id="T_93c54_row1_col6" class="data row1 col6" >0.0361</td>
#       <td id="T_93c54_row1_col7" class="data row1 col7" >0.1066</td>
#       <td id="T_93c54_row1_col8" class="data row1 col8" >0.0791</td>
#       <td id="T_93c54_row1_col9" class="data row1 col9" >0.1323</td>
#       <td id="T_93c54_row1_col10" class="data row1 col10" >79</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Layer-wise Results: $\Delta R^2$ is the main result

# %%
layer_table = results[[
    'dataset', 'layer',
    'heldout_r2_controls_surprisal',
    'heldout_r2_combined',
    'heldout_delta_r2_sae_over_surprisal',
    'delta_sae_over_surprisal_ci_low',
    'delta_sae_over_surprisal_ci_high',
    'n_sae_features_selected_stable_60pct',
]].copy()

layer_table = layer_table.rename(columns={
    'dataset': 'Dataset',
    'layer': 'Layer',
    'heldout_r2_controls_surprisal': 'Controls + surprisal R²',
    'heldout_r2_combined': 'Combined R²',
    'heldout_delta_r2_sae_over_surprisal': 'ΔR² SAE',
    'delta_sae_over_surprisal_ci_low': 'CI low',
    'delta_sae_over_surprisal_ci_high': 'CI high',
    'n_sae_features_selected_stable_60pct': 'Stable features',
})

for dataset in DATASET_ORDER:
    display(Markdown(f'#### {dataset}'))
    df = layer_table[layer_table['Dataset'] == dataset].drop(columns=['Dataset']).sort_values('Layer')
    show_heat_table(
        df,
        heat_cols=['Combined R²', 'ΔR² SAE', 'Stable features'],
        ranges=GLOBAL_HEAT_RANGES,
        caption=f'{dataset}: layer-wise held-out fit and SAE gain. Darker cells use the same scale across datasets.',
    )
# Out:
# #### Provo
# <style type="text/css">
# #T_31c5d th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_31c5d caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_31c5d_row0_col0, #T_31c5d_row0_col1, #T_31c5d_row0_col4, #T_31c5d_row0_col5, #T_31c5d_row1_col0, #T_31c5d_row1_col1, #T_31c5d_row1_col4, #T_31c5d_row1_col5, #T_31c5d_row2_col0, #T_31c5d_row2_col1, #T_31c5d_row2_col4, #T_31c5d_row2_col5, #T_31c5d_row3_col0, #T_31c5d_row3_col1, #T_31c5d_row3_col4, #T_31c5d_row3_col5, #T_31c5d_row4_col0, #T_31c5d_row4_col1, #T_31c5d_row4_col4, #T_31c5d_row4_col5, #T_31c5d_row5_col0, #T_31c5d_row5_col1, #T_31c5d_row5_col4, #T_31c5d_row5_col5, #T_31c5d_row6_col0, #T_31c5d_row6_col1, #T_31c5d_row6_col4, #T_31c5d_row6_col5, #T_31c5d_row7_col0, #T_31c5d_row7_col1, #T_31c5d_row7_col4, #T_31c5d_row7_col5, #T_31c5d_row8_col0, #T_31c5d_row8_col1, #T_31c5d_row8_col4, #T_31c5d_row8_col5, #T_31c5d_row9_col0, #T_31c5d_row9_col1, #T_31c5d_row9_col4, #T_31c5d_row9_col5, #T_31c5d_row10_col0, #T_31c5d_row10_col1, #T_31c5d_row10_col4, #T_31c5d_row10_col5, #T_31c5d_row11_col0, #T_31c5d_row11_col1, #T_31c5d_row11_col4, #T_31c5d_row11_col5 {
#   text-align: center;
# }
# #T_31c5d_row0_col2 {
#   background-color: #2f934d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row0_col3 {
#   background-color: #acdd8e;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row0_col6 {
#   background-color: #dbf1a4;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row1_col2 {
#   background-color: #2f944e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row1_col3 {
#   background-color: #b1df90;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row1_col6 {
#   background-color: #c1e698;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row2_col2 {
#   background-color: #278946;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row2_col3 {
#   background-color: #89ce80;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row2_col6 {
#   background-color: #6dc073;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row3_col2 {
#   background-color: #30954f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row3_col3 {
#   background-color: #b3e091;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row3_col6 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row4_col2 {
#   background-color: #47ae60;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row4_col3 {
#   background-color: #f1fab5;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row4_col6 {
#   background-color: #a6da8b;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row5_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row5_col3 {
#   background-color: #e6f5ac;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row5_col6 {
#   background-color: #b5e092;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row6_col2, #T_31c5d_row8_col2 {
#   background-color: #55b567;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row6_col3 {
#   background-color: #fbfdce;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row6_col6 {
#   background-color: #d7efa2;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row7_col2 {
#   background-color: #51b365;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row7_col3 {
#   background-color: #fafdc8;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row7_col6 {
#   background-color: #e1f3a9;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row8_col3 {
#   background-color: #fbfdcf;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row8_col6 {
#   background-color: #ecf7b1;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row9_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row9_col3 {
#   background-color: #feffdf;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row9_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row10_col2 {
#   background-color: #4fb264;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row10_col3 {
#   background-color: #f9fdc4;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row10_col6 {
#   background-color: #f0f9b4;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row11_col2 {
#   background-color: #49af61;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_31c5d_row11_col3 {
#   background-color: #f5fbb8;
#   color: #000000;
#   text-align: center;
# }
# #T_31c5d_row11_col6 {
#   background-color: #f9fdc5;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_31c5d">
#   <caption>Provo: layer-wise held-out fit and SAE gain. Darker cells use the same scale across datasets.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31c5d_level0_col0" class="col_heading level0 col0" >Layer</th>
#       <th id="T_31c5d_level0_col1" class="col_heading level0 col1" >Controls + surprisal R²</th>
#       <th id="T_31c5d_level0_col2" class="col_heading level0 col2" >Combined R²</th>
#       <th id="T_31c5d_level0_col3" class="col_heading level0 col3" >ΔR² SAE</th>
#       <th id="T_31c5d_level0_col4" class="col_heading level0 col4" >CI low</th>
#       <th id="T_31c5d_level0_col5" class="col_heading level0 col5" >CI high</th>
#       <th id="T_31c5d_level0_col6" class="col_heading level0 col6" >Stable features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31c5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31c5d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_31c5d_row0_col1" class="data row0 col1" >0.1530</td>
#       <td id="T_31c5d_row0_col2" class="data row0 col2" >0.1932</td>
#       <td id="T_31c5d_row0_col3" class="data row0 col3" >0.0402</td>
#       <td id="T_31c5d_row0_col4" class="data row0 col4" >0.0260</td>
#       <td id="T_31c5d_row0_col5" class="data row0 col5" >0.0545</td>
#       <td id="T_31c5d_row0_col6" class="data row0 col6" >27</td>
#     </tr>
#     <tr>
#       <th id="T_31c5d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31c5d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_31c5d_row1_col1" class="data row1 col1" >0.1530</td>
#       <td id="T_31c5d_row1_col2" class="data row1 col2" >0.1920</td>
#       <td id="T_31c5d_row1_col3" class="data row1 col3" >0.0390</td>
#       <td id="T_31c5d_row1_col4" class="data row1 col4" >0.0267</td>
#       <td id="T_31c5d_row1_col5" class="data row1 col5" >0.0516</td>
#       <td id="T_31c5d_row1_col6" class="data row1 col6" >35</td>
#     </tr>
#     <tr>
#       <th id="T_31c5d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31c5d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_31c5d_row2_col1" class="data row2 col1" >0.1530</td>
#       <td id="T_31c5d_row2_col2" class="data row2 col2" >0.2021</td>
#       <td id="T_31c5d_row2_col3" class="data row2 col3" >0.0491</td>
#       <td id="T_31c5d_row2_col4" class="data row2 col4" >0.0334</td>
#       <td id="T_31c5d_row2_col5" class="data row2 col5" >0.0633</td>
#       <td id="T_31c5d_row2_col6" class="data row2 col6" >58</td>
#     </tr>
#     <tr>
#       <th id="T_31c5d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31c5d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_31c5d_row3_col1" class="data row3 col1" >0.1530</td>
#       <td id="T_31c5d_row3_col2" class="data row3 col2" >0.1912</td>
#       <td id="T_31c5d_row3_col3" class="data row3 col3" >0.0382</td>
#       <td id="T_31c5d_row3_col4" class="data row3 col4" >0.0236</td>
#       <td id="T_31c5d_row3_col5" class="data row3 col5" >0.0526</td>
#       <td id="T_31c5d_row3_col6" class="data row3 col6" >85</td>
#     </tr>
#     <tr>
#       <th id="T_31c5d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_31c5d_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_31c5d_row4_col1" class="data row4 col1" >0.1530</td>
#       <td id="T_31c5d_row4_col2" class="data row4 col2" >0.1691</td>
#       <td id="T_31c5d_row4_col3" class="data row4 col3" >0.0161</td>
#       <td id="T_31c5d_row4_col4" class="data row4 col4" >-0.0020</td>
#       <td id="T_31c5d_row4_col5" class="data row4 col5" >0.0336</td>
# #### Natural Stories
# <style type="text/css">
# #T_42b35 th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_42b35 caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_42b35_row0_col0, #T_42b35_row0_col1, #T_42b35_row0_col4, #T_42b35_row0_col5, #T_42b35_row1_col0, #T_42b35_row1_col1, #T_42b35_row1_col4, #T_42b35_row1_col5, #T_42b35_row2_col0, #T_42b35_row2_col1, #T_42b35_row2_col4, #T_42b35_row2_col5, #T_42b35_row3_col0, #T_42b35_row3_col1, #T_42b35_row3_col4, #T_42b35_row3_col5, #T_42b35_row4_col0, #T_42b35_row4_col1, #T_42b35_row4_col4, #T_42b35_row4_col5, #T_42b35_row5_col0, #T_42b35_row5_col1, #T_42b35_row5_col4, #T_42b35_row5_col5, #T_42b35_row6_col0, #T_42b35_row6_col1, #T_42b35_row6_col4, #T_42b35_row6_col5, #T_42b35_row7_col0, #T_42b35_row7_col1, #T_42b35_row7_col4, #T_42b35_row7_col5, #T_42b35_row8_col0, #T_42b35_row8_col1, #T_42b35_row8_col4, #T_42b35_row8_col5, #T_42b35_row9_col0, #T_42b35_row9_col1, #T_42b35_row9_col4, #T_42b35_row9_col5, #T_42b35_row10_col0, #T_42b35_row10_col1, #T_42b35_row10_col4, #T_42b35_row10_col5, #T_42b35_row11_col0, #T_42b35_row11_col1, #T_42b35_row11_col4, #T_42b35_row11_col5 {
#   text-align: center;
# }
# #T_42b35_row0_col2 {
#   background-color: #076d39;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row0_col3 {
#   background-color: #47ae60;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row0_col6 {
#   background-color: #8bce81;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row1_col2 {
#   background-color: #00512e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row1_col3 {
#   background-color: #006435;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row1_col6 {
#   background-color: #2f934d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row2_col2, #T_42b35_row2_col3, #T_42b35_row6_col6, #T_42b35_row9_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row2_col6 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row3_col2, #T_42b35_row5_col6 {
#   background-color: #006034;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row3_col3 {
#   background-color: #248644;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row3_col6, #T_42b35_row10_col6 {
#   background-color: #0a703a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row4_col2 {
#   background-color: #005f34;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row4_col3 {
#   background-color: #238443;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row4_col6 {
#   background-color: #005e33;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row5_col2, #T_42b35_row6_col2 {
#   background-color: #167a3f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row5_col3, #T_42b35_row6_col3 {
#   background-color: #84cb7e;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row7_col2 {
#   background-color: #12763d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row7_col3 {
#   background-color: #74c477;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row7_col6 {
#   background-color: #006335;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row8_col2 {
#   background-color: #0b713b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row8_col3 {
#   background-color: #58b669;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row8_col6 {
#   background-color: #00492b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row9_col2 {
#   background-color: #15793e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row9_col3 {
#   background-color: #81ca7d;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row10_col2 {
#   background-color: #329850;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row10_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row11_col2 {
#   background-color: #349a52;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_42b35_row11_col3 {
#   background-color: #eef9b3;
#   color: #000000;
#   text-align: center;
# }
# #T_42b35_row11_col6 {
#   background-color: #a6da8b;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_42b35">
#   <caption>Natural Stories: layer-wise held-out fit and SAE gain. Darker cells use the same scale across datasets.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42b35_level0_col0" class="col_heading level0 col0" >Layer</th>
#       <th id="T_42b35_level0_col1" class="col_heading level0 col1" >Controls + surprisal R²</th>
#       <th id="T_42b35_level0_col2" class="col_heading level0 col2" >Combined R²</th>
#       <th id="T_42b35_level0_col3" class="col_heading level0 col3" >ΔR² SAE</th>
#       <th id="T_42b35_level0_col4" class="col_heading level0 col4" >CI low</th>
#       <th id="T_42b35_level0_col5" class="col_heading level0 col5" >CI high</th>
#       <th id="T_42b35_level0_col6" class="col_heading level0 col6" >Stable features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42b35_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_42b35_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_42b35_row0_col1" class="data row0 col1" >0.1692</td>
#       <td id="T_42b35_row0_col2" class="data row0 col2" >0.2345</td>
#       <td id="T_42b35_row0_col3" class="data row0 col3" >0.0653</td>
#       <td id="T_42b35_row0_col4" class="data row0 col4" >0.0386</td>
#       <td id="T_42b35_row0_col5" class="data row0 col5" >0.0872</td>
#       <td id="T_42b35_row0_col6" class="data row0 col6" >50</td>
#     </tr>
#     <tr>
#       <th id="T_42b35_level0_row1" class="row_heading level0 row1" >13</th>
#       <td id="T_42b35_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_42b35_row1_col1" class="data row1 col1" >0.1692</td>
#       <td id="T_42b35_row1_col2" class="data row1 col2" >0.2639</td>
#       <td id="T_42b35_row1_col3" class="data row1 col3" >0.0947</td>
#       <td id="T_42b35_row1_col4" class="data row1 col4" >0.0680</td>
#       <td id="T_42b35_row1_col5" class="data row1 col5" >0.1204</td>
#       <td id="T_42b35_row1_col6" class="data row1 col6" >77</td>
#     </tr>
#     <tr>
#       <th id="T_42b35_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_42b35_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_42b35_row2_col1" class="data row2 col1" >0.1692</td>
#       <td id="T_42b35_row2_col2" class="data row2 col2" >0.2759</td>
#       <td id="T_42b35_row2_col3" class="data row2 col3" >0.1066</td>
#       <td id="T_42b35_row2_col4" class="data row2 col4" >0.0791</td>
#       <td id="T_42b35_row2_col5" class="data row2 col5" >0.1323</td>
#       <td id="T_42b35_row2_col6" class="data row2 col6" >79</td>
#     </tr>
#     <tr>
#       <th id="T_42b35_level0_row3" class="row_heading level0 row3" >15</th>
#       <td id="T_42b35_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_42b35_row3_col1" class="data row3 col1" >0.1692</td>
#       <td id="T_42b35_row3_col2" class="data row3 col2" >0.2484</td>
#       <td id="T_42b35_row3_col3" class="data row3 col3" >0.0792</td>
#       <td id="T_42b35_row3_col4" class="data row3 col4" >0.0374</td>
#       <td id="T_42b35_row3_col5" class="data row3 col5" >0.1127</td>
#       <td id="T_42b35_row3_col6" class="data row3 col6" >92</td>
#     </tr>
#     <tr>
#       <th id="T_42b35_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_42b35_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_42b35_row4_col1" class="data row4 col1" >0.1692</td>
#       <td id="T_42b35_row4_col2" class="data row4 col2" >0.2490</td>
#       <td id="T_42b35_row4_col3" class="data row4 col3" >0.0798</td>
#       <td id="T_42b35_row4_col4" class="data row4 col4" >0.0526</td>
#       <td id="T_42b35_row4_col5" class="data row4 col5" >0.1049</td>
#       <td id="T_42b35_row4_col6" class="data row4 col6" >100</td>
#     </tr>
#     <tr>
#       <th id="T_42b35_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_42b35_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_42b35_row5_col1" class="data row5 col1" >0.1692</td>
#       <td id="T_42b35_row5_col2" class="data row5 col2" >0.2195</td>
#       <td id="T_42b35_row5_col3" class="data row5 col3"

# %% [markdown]
# Gain Heatmap: cells represents the held-out $\Delta R^2$ from adding SAE features beyond lexical controls and surprisal.
#
# Strongest results is layer 3 in both datasets.

# %%
gain = results.pivot_table(
    index='dataset',
    columns='layer',
    values='heldout_delta_r2_sae_over_surprisal',
)
gain = gain.loc[DATASET_ORDER, list(range(1, 13))]

fig, ax = plt.subplots(figsize=(11, 2.4))
im = ax.imshow(
    gain.to_numpy(),
    aspect='auto',
    cmap=HEATMAP_CMAP,
    vmin=GLOBAL_HEAT_RANGES['ΔR² SAE'][0],
    vmax=GLOBAL_HEAT_RANGES['ΔR² SAE'][1],
)

ax.set_xticks(np.arange(gain.shape[1]))
ax.set_xticklabels(gain.columns)
ax.set_yticks(np.arange(gain.shape[0]))
ax.set_yticklabels(gain.index)
ax.set_xlabel('GPT-2-small residual-stream layer')
ax.set_title('Held-out SAE gain beyond surprisal (ΔR²)')

for i in range(gain.shape[0]):
    for j in range(gain.shape[1]):
        val = gain.iloc[i, j]
        text_color = 'white' if val > GLOBAL_HEAT_RANGES['ΔR² SAE'][1] * 0.58 else 'black'
        ax.text(j, i, f'{val:.3f}', ha='center', va='center', color=text_color, fontsize=9)

cbar = fig.colorbar(im, ax=ax, fraction=0.025, pad=0.02)
cbar.set_label('ΔR² SAE over surprisal')
fig.tight_layout()
plt.show()

# %% [markdown]
# Layer-wise SAE Gain

# %%
plt.rcParams.update({
    'font.size': 11,
    'axes.spines.top': False,
    'axes.spines.right': False,
})

fig, axes = plt.subplots(1, 2, figsize=(11, 4.2), sharey=False)
order = DATASET_ORDER

for ax, dataset in zip(axes, order):
    df = results[results['dataset'] == dataset].sort_values('layer')
    x = df['layer'].to_numpy()
    y = df['heldout_delta_r2_sae_over_surprisal'].to_numpy()
    lo = df['delta_sae_over_surprisal_ci_low'].to_numpy()
    hi = df['delta_sae_over_surprisal_ci_high'].to_numpy()
    color = COLORS[dataset]

    ax.axhline(0, color='#666666', linewidth=1)
    ax.fill_between(x, lo, hi, color=color, alpha=0.18, linewidth=0)
    ax.plot(x, y, color=color, marker='o', linewidth=2.2)

    best = df.loc[df['heldout_delta_r2_sae_over_surprisal'].idxmax()]
    ax.scatter(best['layer'], best['heldout_delta_r2_sae_over_surprisal'], s=90, color=color, edgecolor='black', zorder=3)
    ax.annotate(
        f"best L{int(best['layer'])}",
        xy=(best['layer'], best['heldout_delta_r2_sae_over_surprisal']),
        xytext=(best['layer'] + 0.25, best['heldout_delta_r2_sae_over_surprisal'] + 0.006),
        fontsize=10,
    )

    ax.set_title(dataset)
    ax.set_xlabel('GPT-2-small residual-stream layer')
    ax.set_ylabel('Held-out Delta R2: SAE beyond surprisal')
    ax.set_xticks(range(1, 13))

fig.suptitle('Layer-wise SAE gain beyond surprisal', y=1.04, fontsize=14)
fig.tight_layout()
plt.show()

# %% [markdown]
# Feature-selection Stability: showing where do we have enough stable features to interpret.

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4.2), sharey=False)

for ax, dataset in zip(axes, DATASET_ORDER):
    df = results[results['dataset'] == dataset].sort_values('layer')
    color = COLORS[dataset]
    ax.bar(df['layer'], df['n_sae_features_selected_stable_60pct'], color=color, alpha=0.86)
    ax.set_title(dataset)
    ax.set_xlabel('Layer')
    ax.set_ylabel('Features selected in at least 60% of folds')
    ax.set_xticks(range(1, 13))

fig.suptitle('Stable selected SAE features by layer', y=1.04, fontsize=14)
fig.tight_layout()
plt.show()

# %% [markdown]
# SAE Feature Activation Percentage: in word-level, for every word and layer compute:
#
# **percentage active = active SAE features / total SAE features × 100**
#
# This shows the mean % across words. The shaded band shows the middle, 50%, of words. Showing how many SAE features are being used per word at each layer.

# %%
def infer_sae_width(corpus):
    max_id = -1
    for layer in range(1, 13):
        sparse = np.load(PROJECT_ROOT / f'results/sae/{corpus}_sae_L{layer:02d}_sparse.npz', allow_pickle=True)
        layer_max = max((int(ids.max()) if len(ids) else -1) for ids in sparse['feat_indices'])
        max_id = max(max_id, layer_max)
    return max_id + 1

activation_frames = []
for corpus, dataset in [('provo', 'Provo'), ('natural_stories', 'Natural Stories')]:
    width = infer_sae_width(corpus)
    meta = pd.read_csv(PROJECT_ROOT / f'results/sae/{corpus}_sae_metadata.csv')
    meta['Dataset'] = dataset
    meta['SAE width'] = width
    meta['Active %'] = meta['n_active'] / width * 100
    activation_frames.append(meta[['Dataset', 'layer', 'n_active', 'Active %', 'SAE width']])

activation = pd.concat(activation_frames, ignore_index=True)
activation_summary = (
    activation
    .groupby(['Dataset', 'layer'], as_index=False)
    .agg(
        mean_active_features=('n_active', 'mean'),
        median_active_features=('n_active', 'median'),
        q25_active_features=('n_active', lambda x: x.quantile(0.25)),
        q75_active_features=('n_active', lambda x: x.quantile(0.75)),
        mean_active_pct=('Active %', 'mean'),
        median_active_pct=('Active %', 'median'),
        q25_active_pct=('Active %', lambda x: x.quantile(0.25)),
        q75_active_pct=('Active %', lambda x: x.quantile(0.75)),
        words=('n_active', 'size'),
        sae_width=('SAE width', 'first'),
    )
)

fig, axes = plt.subplots(1, 2, figsize=(11, 4.2), sharey=True)

for ax, dataset in zip(axes, ['Provo', 'Natural Stories']):
    df = activation_summary[activation_summary['Dataset'] == dataset].sort_values('layer')
    x = df['layer'].to_numpy()
    mean = df['mean_active_pct'].to_numpy()
    q25 = df['q25_active_pct'].to_numpy()
    q75 = df['q75_active_pct'].to_numpy()
    color = COLORS[dataset]

    ax.fill_between(x, q25, q75, color=color, alpha=0.18, linewidth=0, label='middle 50% of words')
    ax.plot(x, mean, color=color, marker='o', linewidth=2.2, label='mean across words')

    peak = df.loc[df['mean_active_pct'].idxmax()]
    ax.scatter(peak['layer'], peak['mean_active_pct'], s=85, color=color, edgecolor='black', zorder=3)
    ax.annotate(
        f"peak L{int(peak['layer'])}\n{peak['mean_active_pct']:.2f}%",
        xy=(peak['layer'], peak['mean_active_pct']),
        xytext=(peak['layer'] + 0.25, peak['mean_active_pct'] + 0.015),
        fontsize=9,
    )

    ax.set_title(dataset)
    ax.set_xlabel('GPT-2-small residual-stream layer')
    ax.set_xticks(range(1, 13))
    ax.grid(axis='y', alpha=0.2)

axes[0].set_ylabel('SAE features active per word (%)')
axes[1].legend(frameon=False, loc='upper left')
fig.suptitle('Word-level SAE activation sparsity by layer', y=1.04, fontsize=14)
# fig.text(0.5, -0.02, 'SAE width inferred from saved feature IDs: 24,576 features. Values are small because SAEs are intentionally sparse.', ha='center', fontsize=10)
fig.tight_layout()
plt.show()

# Numeric version of the plotted summary.
activation_table = activation_summary[[
    'Dataset', 'layer', 'mean_active_features', 'median_active_features',
    'mean_active_pct', 'median_active_pct', 'words', 'sae_width'
]].rename(columns={
    'layer': 'Layer',
    'mean_active_features': 'Mean active features/word',
    'median_active_features': 'Median active features/word',
    'mean_active_pct': 'Mean active %',
    'median_active_pct': 'Median active %',
    'words': 'Word-layer rows',
    'sae_width': 'SAE width',
})

show_heat_table(
    activation_table,
    heat_cols=['Mean active features/word', 'Median active features/word', 'Mean active %', 'Median active %'],
    # caption='Numeric summary behind the activation figure. Darker cells indicate more SAE features active per word.',
)
# Out:
# <style type="text/css">
# #T_2b248 th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_2b248 caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_2b248_row0_col0, #T_2b248_row0_col1, #T_2b248_row0_col6, #T_2b248_row0_col7, #T_2b248_row1_col0, #T_2b248_row1_col1, #T_2b248_row1_col6, #T_2b248_row1_col7, #T_2b248_row2_col0, #T_2b248_row2_col1, #T_2b248_row2_col6, #T_2b248_row2_col7, #T_2b248_row3_col0, #T_2b248_row3_col1, #T_2b248_row3_col6, #T_2b248_row3_col7, #T_2b248_row4_col0, #T_2b248_row4_col1, #T_2b248_row4_col6, #T_2b248_row4_col7, #T_2b248_row5_col0, #T_2b248_row5_col1, #T_2b248_row5_col6, #T_2b248_row5_col7, #T_2b248_row6_col0, #T_2b248_row6_col1, #T_2b248_row6_col6, #T_2b248_row6_col7, #T_2b248_row7_col0, #T_2b248_row7_col1, #T_2b248_row7_col6, #T_2b248_row7_col7, #T_2b248_row8_col0, #T_2b248_row8_col1, #T_2b248_row8_col6, #T_2b248_row8_col7, #T_2b248_row9_col0, #T_2b248_row9_col1, #T_2b248_row9_col6, #T_2b248_row9_col7, #T_2b248_row10_col0, #T_2b248_row10_col1, #T_2b248_row10_col6, #T_2b248_row10_col7, #T_2b248_row11_col0, #T_2b248_row11_col1, #T_2b248_row11_col6, #T_2b248_row11_col7, #T_2b248_row12_col0, #T_2b248_row12_col1, #T_2b248_row12_col6, #T_2b248_row12_col7, #T_2b248_row13_col0, #T_2b248_row13_col1, #T_2b248_row13_col6, #T_2b248_row13_col7, #T_2b248_row14_col0, #T_2b248_row14_col1, #T_2b248_row14_col6, #T_2b248_row14_col7, #T_2b248_row15_col0, #T_2b248_row15_col1, #T_2b248_row15_col6, #T_2b248_row15_col7, #T_2b248_row16_col0, #T_2b248_row16_col1, #T_2b248_row16_col6, #T_2b248_row16_col7, #T_2b248_row17_col0, #T_2b248_row17_col1, #T_2b248_row17_col6, #T_2b248_row17_col7, #T_2b248_row18_col0, #T_2b248_row18_col1, #T_2b248_row18_col6, #T_2b248_row18_col7, #T_2b248_row19_col0, #T_2b248_row19_col1, #T_2b248_row19_col6, #T_2b248_row19_col7, #T_2b248_row20_col0, #T_2b248_row20_col1, #T_2b248_row20_col6, #T_2b248_row20_col7, #T_2b248_row21_col0, #T_2b248_row21_col1, #T_2b248_row21_col6, #T_2b248_row21_col7, #T_2b248_row22_col0, #T_2b248_row22_col1, #T_2b248_row22_col6, #T_2b248_row22_col7, #T_2b248_row23_col0, #T_2b248_row23_col1, #T_2b248_row23_col6, #T_2b248_row23_col7 {
#   text-align: center;
# }
# #T_2b248_row0_col2, #T_2b248_row0_col3, #T_2b248_row0_col4, #T_2b248_row0_col5 {
#   background-color: #ffffe5;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row1_col2, #T_2b248_row1_col4 {
#   background-color: #fbfed0;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row1_col3, #T_2b248_row1_col5 {
#   background-color: #fbfdce;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row2_col2, #T_2b248_row2_col4 {
#   background-color: #f5fbb8;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row2_col3, #T_2b248_row2_col5 {
#   background-color: #f0f9b4;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row3_col2, #T_2b248_row3_col4 {
#   background-color: #ddf2a6;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row3_col3 {
#   background-color: #d9f0a3;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row3_col5 {
#   background-color: #daf0a4;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row4_col2, #T_2b248_row4_col4 {
#   background-color: #bae394;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row4_col3, #T_2b248_row4_col5, #T_2b248_row16_col3, #T_2b248_row16_col5 {
#   background-color: #b2df90;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row5_col2, #T_2b248_row5_col4 {
#   background-color: #72c376;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row5_col3, #T_2b248_row5_col5, #T_2b248_row17_col3, #T_2b248_row17_col5 {
#   background-color: #6bc072;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row6_col2, #T_2b248_row6_col4 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row6_col3, #T_2b248_row6_col5 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row7_col2, #T_2b248_row7_col4 {
#   background-color: #258745;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row7_col3, #T_2b248_row7_col5, #T_2b248_row19_col3, #T_2b248_row19_col5 {
#   background-color: #228343;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row8_col2, #T_2b248_row8_col4 {
#   background-color: #006335;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row8_col3, #T_2b248_row8_col5 {
#   background-color: #005f34;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row9_col2, #T_2b248_row9_col3, #T_2b248_row9_col4, #T_2b248_row9_col5 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row10_col2, #T_2b248_row10_col3, #T_2b248_row10_col4, #T_2b248_row10_col5 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row11_col2, #T_2b248_row11_col3, #T_2b248_row11_col4, #T_2b248_row11_col5 {
#   background-color: #13773d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row12_col2, #T_2b248_row12_col4 {
#   background-color: #fdfedb;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row12_col3, #T_2b248_row12_col5 {
#   background-color: #fcfed7;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row13_col2, #T_2b248_row13_col4 {
#   background-color: #f8fcbd;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row13_col3, #T_2b248_row13_col5 {
#   background-color: #f9fdc4;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row14_col2, #T_2b248_row14_col4 {
#   background-color: #eaf7af;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row14_col3, #T_2b248_row14_col5 {
#   background-color: #edf8b2;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row15_col2, #T_2b248_row15_col4 {
#   background-color: #dcf1a5;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row15_col3, #T_2b248_row15_col5 {
#   background-color: #d5eea1;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row16_col2, #T_2b248_row16_col4 {
#   background-color: #b8e293;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row17_col2, #T_2b248_row17_col4 {
#   background-color: #74c477;
#   color: #000000;
#   text-align: center;
# }
# #T_2b248_row18_col2, #T_2b248_row18_col4 {
#   background-color: #47ae60;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row18_col3 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row18_col5 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row19_col2, #T_2b248_row19_col4, #T_2b248_row23_col2, #T_2b248_row23_col3, #T_2b248_row23_col4, #T_2b248_row23_col5 {
#   background-color: #268846;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row20_col2, #T_2b248_row20_col4 {
#   background-color: #026a38;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row20_col3, #T_2b248_row20_col5 {
#   background-color: #006737;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row21_col2, #T_2b248_row21_col4 {
#   background-color: #00512e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row21_col3, #T_2b248_row21_col5 {
#   background-color: #004e2d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row22_col2, #T_2b248_row22_col4 {
#   background-color: #339951;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b248_row22_col3, #T_2b248_row22_col5 {
#   background-color: #30954f;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_2b248">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b248_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_2b248_level0_col1" class="col_heading level0 col1" >Layer</th>
#       <th id="T_2b248_level0_col2" class="col_heading level0 col2" >Mean active features/word</th>
#       <th id="T_2b248_level0_col3" class="col_heading level0 col3" >Median active features/word</th>
#       <th id="T_2b248_level0_col4" class="col_heading level0 col4" >Mean active %</th>
#       <th id="T_2b248_level0_col5" class="col_heading level0 col5" >Median active %</th>
#       <th id="T_2b248_level0_col6" class="col_heading level0 col6" >Word-layer rows</th>
#       <th id="T_2b248_level0_col7" class="col_heading level0 col7" >SAE width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b248_level0_row0" class="row_heading level0 row0"

# %% [markdown]
# Candidate Features for Interpretation: some testing before the real feature interepretation. This is only on the best layer for both datasets

# %%
candidate_tables = []
for corpus, dataset in [('provo', 'Provo'), ('natural_stories', 'Natural Stories')]:
    top = pd.read_csv(PROJECT_ROOT / f'results/regression/{corpus}_sae_top_features.csv')
    best_layer = int(best_summary.loc[best_summary['Dataset'] == dataset, 'Best layer'].iloc[0])
    cand = top[(top['layer'] == best_layer) & (top['selection_rate'] == 1.0) & (top['sign_agreement'] == 1.0)].copy()
    cand['abs_coef'] = cand['coef'].abs()
    cand = cand.sort_values('abs_coef', ascending=False).head(10)
    cand = cand[['layer', 'feature_id', 'coef', 'abs_coef', 'direction', 'pct_active', 'selection_rate', 'sign_agreement']]
    cand = cand.rename(columns={
        'layer': 'Layer',
        'feature_id': 'Feature ID',
        'coef': 'Coefficient',
        'abs_coef': '|Coefficient|',
        'direction': 'Direction',
        'pct_active': '% active',
        'selection_rate': 'Selection rate',
        'sign_agreement': 'Sign agreement',
    })
    candidate_tables.append((dataset, cand))

feature_ranges = {
    '|Coefficient|': (0, max(float(c['|Coefficient|'].max()) for _, c in candidate_tables if len(c))),
    '% active': (0, max(float(c['% active'].max()) for _, c in candidate_tables if len(c))),
    'Selection rate': (0, 1),
    'Sign agreement': (0, 1),
}

for dataset, cand in candidate_tables:
    # display(Markdown(f'#### {dataset}: stable candidate features from the best layer'))
    show_heat_table(
        cand,
        heat_cols=['|Coefficient|', '% active', 'Selection rate', 'Sign agreement'],
        ranges=feature_ranges,
        # caption='Candidate features to inspect next. Coefficient sign shows direction; shading uses magnitude and stability.',
    )
# Out:
# <style type="text/css">
# #T_2b0b3 th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_2b0b3 caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_2b0b3_row0_col0, #T_2b0b3_row0_col1, #T_2b0b3_row0_col2, #T_2b0b3_row0_col4, #T_2b0b3_row1_col0, #T_2b0b3_row1_col1, #T_2b0b3_row1_col2, #T_2b0b3_row1_col4, #T_2b0b3_row2_col0, #T_2b0b3_row2_col1, #T_2b0b3_row2_col2, #T_2b0b3_row2_col4, #T_2b0b3_row3_col0, #T_2b0b3_row3_col1, #T_2b0b3_row3_col2, #T_2b0b3_row3_col4, #T_2b0b3_row4_col0, #T_2b0b3_row4_col1, #T_2b0b3_row4_col2, #T_2b0b3_row4_col4, #T_2b0b3_row5_col0, #T_2b0b3_row5_col1, #T_2b0b3_row5_col2, #T_2b0b3_row5_col4, #T_2b0b3_row6_col0, #T_2b0b3_row6_col1, #T_2b0b3_row6_col2, #T_2b0b3_row6_col4, #T_2b0b3_row7_col0, #T_2b0b3_row7_col1, #T_2b0b3_row7_col2, #T_2b0b3_row7_col4, #T_2b0b3_row8_col0, #T_2b0b3_row8_col1, #T_2b0b3_row8_col2, #T_2b0b3_row8_col4, #T_2b0b3_row9_col0, #T_2b0b3_row9_col1, #T_2b0b3_row9_col2, #T_2b0b3_row9_col4 {
#   text-align: center;
# }
# #T_2b0b3_row0_col3, #T_2b0b3_row0_col6, #T_2b0b3_row0_col7, #T_2b0b3_row1_col6, #T_2b0b3_row1_col7, #T_2b0b3_row2_col6, #T_2b0b3_row2_col7, #T_2b0b3_row3_col6, #T_2b0b3_row3_col7, #T_2b0b3_row4_col6, #T_2b0b3_row4_col7, #T_2b0b3_row5_col6, #T_2b0b3_row5_col7, #T_2b0b3_row6_col6, #T_2b0b3_row6_col7, #T_2b0b3_row7_col6, #T_2b0b3_row7_col7, #T_2b0b3_row8_col6, #T_2b0b3_row8_col7, #T_2b0b3_row9_col6, #T_2b0b3_row9_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b0b3_row0_col5, #T_2b0b3_row1_col5 {
#   background-color: #fbfdcf;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row1_col3 {
#   background-color: #389f55;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b0b3_row2_col3 {
#   background-color: #39a056;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2b0b3_row2_col5 {
#   background-color: #edf8b1;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row3_col3 {
#   background-color: #77c679;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row3_col5 {
#   background-color: #fafdc9;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row4_col3 {
#   background-color: #7fc97c;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row4_col5 {
#   background-color: #feffdf;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row5_col3 {
#   background-color: #9cd687;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row5_col5 {
#   background-color: #f6fcb8;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row6_col3 {
#   background-color: #a7db8c;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row6_col5 {
#   background-color: #feffe1;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row7_col3 {
#   background-color: #afde8f;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row7_col5 {
#   background-color: #daf0a4;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row8_col3 {
#   background-color: #c4e799;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row8_col5 {
#   background-color: #fafdcc;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row9_col3 {
#   background-color: #e3f4aa;
#   color: #000000;
#   text-align: center;
# }
# #T_2b0b3_row9_col5 {
#   background-color: #fcfed4;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_2b0b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b0b3_level0_col0" class="col_heading level0 col0" >Layer</th>
#       <th id="T_2b0b3_level0_col1" class="col_heading level0 col1" >Feature ID</th>
#       <th id="T_2b0b3_level0_col2" class="col_heading level0 col2" >Coefficient</th>
#       <th id="T_2b0b3_level0_col3" class="col_heading level0 col3" >|Coefficient|</th>
#       <th id="T_2b0b3_level0_col4" class="col_heading level0 col4" >Direction</th>
#       <th id="T_2b0b3_level0_col5" class="col_heading level0 col5" >% active</th>
#       <th id="T_2b0b3_level0_col6" class="col_heading level0 col6" >Selection rate</th>
#       <th id="T_2b0b3_level0_col7" class="col_heading level0 col7" >Sign agreement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b0b3_level0_row0" class="row_heading level0 row0" >106</th>
#       <td id="T_2b0b3_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_2b0b3_row0_col1" class="data row0 col1" >3990</td>
#       <td id="T_2b0b3_row0_col2" class="data row0 col2" >0.0109</td>
#       <td id="T_2b0b3_row0_col3" class="data row0 col3" >0.0109</td>
#       <td id="T_2b0b3_row0_col4" class="data row0 col4" >positive</td>
#       <td id="T_2b0b3_row0_col5" class="data row0 col5" >3.5361</td>
#       <td id="T_2b0b3_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_2b0b3_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row1" class="row_heading level0 row1" >107</th>
#       <td id="T_2b0b3_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_2b0b3_row1_col1" class="data row1 col1" >14509</td>
#       <td id="T_2b0b3_row1_col2" class="data row1 col2" >-0.0072</td>
#       <td id="T_2b0b3_row1_col3" class="data row1 col3" >0.0072</td>
#       <td id="T_2b0b3_row1_col4" class="data row1 col4" >negative</td>
#       <td id="T_2b0b3_row1_col5" class="data row1 col5" >3.4601</td>
#       <td id="T_2b0b3_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_2b0b3_row1_col7" class="data row1 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row2" class="row_heading level0 row2" >108</th>
#       <td id="T_2b0b3_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2b0b3_row2_col1" class="data row2 col1" >15739</td>
#       <td id="T_2b0b3_row2_col2" class="data row2 col2" >-0.0072</td>
#       <td id="T_2b0b3_row2_col3" class="data row2 col3" >0.0072</td>
#       <td id="T_2b0b3_row2_col4" class="data row2 col4" >negative</td>
#       <td id="T_2b0b3_row2_col5" class="data row2 col5" >9.2776</td>
#       <td id="T_2b0b3_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_2b0b3_row2_col7" class="data row2 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row3" class="row_heading level0 row3" >110</th>
#       <td id="T_2b0b3_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_2b0b3_row3_col1" class="data row3 col1" >18231</td>
#       <td id="T_2b0b3_row3_col2" class="data row3 col2" >-0.0055</td>
#       <td id="T_2b0b3_row3_col3" class="data row3 col3" >0.0055</td>
#       <td id="T_2b0b3_row3_col4" class="data row3 col4" >negative</td>
#       <td id="T_2b0b3_row3_col5" class="data row3 col5" >4.4106</td>
#       <td id="T_2b0b3_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_2b0b3_row3_col7" class="data row3 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row4" class="row_heading level0 row4" >111</th>
#       <td id="T_2b0b3_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_2b0b3_row4_col1" class="data row4 col1" >24460</td>
#       <td id="T_2b0b3_row4_col2" class="data row4 col2" >-0.0053</td>
#       <td id="T_2b0b3_row4_col3" class="data row4 col3" >0.0053</td>
#       <td id="T_2b0b3_row4_col4" class="data row4 col4" >negative</td>
#       <td id="T_2b0b3_row4_col5" class="data row4 col5" >0.9506</td>
#       <td id="T_2b0b3_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_2b0b3_row4_col7" class="data row4 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row5" class="row_heading level0 row5" >112</th>
#       <td id="T_2b0b3_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_2b0b3_row5_col1" class="data row5 col1" >10596</td>
#       <td id="T_2b0b3_row5_col2" class="data row5 col2" >0.0045</td>
#       <td id="T_2b0b3_row5_col3" class="data row5 col3" >0.0045</td>
#       <td id="T_2b0b3_row5_col4" class="data row5 col4" >positive</td>
#       <td id="T_2b0b3_row5_col5" class="data row5 col5" >7.0342</td>
#       <td id="T_2b0b3_row5_col6" class="data row5 col6" >1.0000</td>
#       <td id="T_2b0b3_row5_col7" class="data row5 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2b0b3_level0_row6" class="row_heading level0 row6" >113</th>
#       <td id="T_2b0b3_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_2b0b3_row6_
# <style type="text/css">
# #T_2d4a7 th {
#   text-align: center;
#   font-weight: 600;
# }
# #T_2d4a7 caption {
#   caption-side: top;
#   font-weight: 600;
#   font-size: 14px;
# }
# #T_2d4a7_row0_col0, #T_2d4a7_row0_col1, #T_2d4a7_row0_col2, #T_2d4a7_row0_col4, #T_2d4a7_row1_col0, #T_2d4a7_row1_col1, #T_2d4a7_row1_col2, #T_2d4a7_row1_col4, #T_2d4a7_row2_col0, #T_2d4a7_row2_col1, #T_2d4a7_row2_col2, #T_2d4a7_row2_col4, #T_2d4a7_row3_col0, #T_2d4a7_row3_col1, #T_2d4a7_row3_col2, #T_2d4a7_row3_col4, #T_2d4a7_row4_col0, #T_2d4a7_row4_col1, #T_2d4a7_row4_col2, #T_2d4a7_row4_col4, #T_2d4a7_row5_col0, #T_2d4a7_row5_col1, #T_2d4a7_row5_col2, #T_2d4a7_row5_col4, #T_2d4a7_row6_col0, #T_2d4a7_row6_col1, #T_2d4a7_row6_col2, #T_2d4a7_row6_col4, #T_2d4a7_row7_col0, #T_2d4a7_row7_col1, #T_2d4a7_row7_col2, #T_2d4a7_row7_col4, #T_2d4a7_row8_col0, #T_2d4a7_row8_col1, #T_2d4a7_row8_col2, #T_2d4a7_row8_col4, #T_2d4a7_row9_col0, #T_2d4a7_row9_col1, #T_2d4a7_row9_col2, #T_2d4a7_row9_col4 {
#   text-align: center;
# }
# #T_2d4a7_row0_col3 {
#   background-color: #0a703a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row0_col5 {
#   background-color: #177b3f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row0_col6, #T_2d4a7_row0_col7, #T_2d4a7_row1_col5, #T_2d4a7_row1_col6, #T_2d4a7_row1_col7, #T_2d4a7_row2_col6, #T_2d4a7_row2_col7, #T_2d4a7_row3_col6, #T_2d4a7_row3_col7, #T_2d4a7_row4_col6, #T_2d4a7_row4_col7, #T_2d4a7_row5_col6, #T_2d4a7_row5_col7, #T_2d4a7_row6_col6, #T_2d4a7_row6_col7, #T_2d4a7_row7_col6, #T_2d4a7_row7_col7, #T_2d4a7_row8_col6, #T_2d4a7_row8_col7, #T_2d4a7_row9_col6, #T_2d4a7_row9_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row1_col3 {
#   background-color: #13773d;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row2_col3 {
#   background-color: #30954f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row2_col5 {
#   background-color: #fcfed3;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row3_col3 {
#   background-color: #49af61;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row3_col5 {
#   background-color: #e7f6ad;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row4_col3 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row4_col5 {
#   background-color: #c4e799;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row5_col3 {
#   background-color: #95d385;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row5_col5 {
#   background-color: #feffe2;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row6_col3 {
#   background-color: #9ad587;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row6_col5 {
#   background-color: #d9f0a3;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row7_col3 {
#   background-color: #a7db8c;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row7_col5 {
#   background-color: #fdfedb;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row8_col3 {
#   background-color: #a9db8c;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row8_col5 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_2d4a7_row9_col3 {
#   background-color: #b1df90;
#   color: #000000;
#   text-align: center;
# }
# #T_2d4a7_row9_col5 {
#   background-color: #feffde;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_2d4a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d4a7_level0_col0" class="col_heading level0 col0" >Layer</th>
#       <th id="T_2d4a7_level0_col1" class="col_heading level0 col1" >Feature ID</th>
#       <th id="T_2d4a7_level0_col2" class="col_heading level0 col2" >Coefficient</th>
#       <th id="T_2d4a7_level0_col3" class="col_heading level0 col3" >|Coefficient|</th>
#       <th id="T_2d4a7_level0_col4" class="col_heading level0 col4" >Direction</th>
#       <th id="T_2d4a7_level0_col5" class="col_heading level0 col5" >% active</th>
#       <th id="T_2d4a7_level0_col6" class="col_heading level0 col6" >Selection rate</th>
#       <th id="T_2d4a7_level0_col7" class="col_heading level0 col7" >Sign agreement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d4a7_level0_row0" class="row_heading level0 row0" >219</th>
#       <td id="T_2d4a7_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_2d4a7_row0_col1" class="data row0 col1" >24573</td>
#       <td id="T_2d4a7_row0_col2" class="data row0 col2" >-0.0092</td>
#       <td id="T_2d4a7_row0_col3" class="data row0 col3" >0.0092</td>
#       <td id="T_2d4a7_row0_col4" class="data row0 col4" >negative</td>
#       <td id="T_2d4a7_row0_col5" class="data row0 col5" >42.8753</td>
#       <td id="T_2d4a7_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_2d4a7_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row1" class="row_heading level0 row1" >220</th>
#       <td id="T_2d4a7_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_2d4a7_row1_col1" class="data row1 col1" >12935</td>
#       <td id="T_2d4a7_row1_col2" class="data row1 col2" >-0.0088</td>
#       <td id="T_2d4a7_row1_col3" class="data row1 col3" >0.0088</td>
#       <td id="T_2d4a7_row1_col4" class="data row1 col4" >negative</td>
#       <td id="T_2d4a7_row1_col5" class="data row1 col5" >54.0699</td>
#       <td id="T_2d4a7_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_2d4a7_row1_col7" class="data row1 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row2" class="row_heading level0 row2" >221</th>
#       <td id="T_2d4a7_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2d4a7_row2_col1" class="data row2 col1" >2765</td>
#       <td id="T_2d4a7_row2_col2" class="data row2 col2" >0.0076</td>
#       <td id="T_2d4a7_row2_col3" class="data row2 col3" >0.0076</td>
#       <td id="T_2d4a7_row2_col4" class="data row2 col4" >positive</td>
#       <td id="T_2d4a7_row2_col5" class="data row2 col5" >2.8109</td>
#       <td id="T_2d4a7_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_2d4a7_row2_col7" class="data row2 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row3" class="row_heading level0 row3" >222</th>
#       <td id="T_2d4a7_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_2d4a7_row3_col1" class="data row3 col1" >18381</td>
#       <td id="T_2d4a7_row3_col2" class="data row3 col2" >0.0066</td>
#       <td id="T_2d4a7_row3_col3" class="data row3 col3" >0.0066</td>
#       <td id="T_2d4a7_row3_col4" class="data row3 col4" >positive</td>
#       <td id="T_2d4a7_row3_col5" class="data row3 col5" >10.4041</td>
#       <td id="T_2d4a7_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_2d4a7_row3_col7" class="data row3 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row4" class="row_heading level0 row4" >223</th>
#       <td id="T_2d4a7_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_2d4a7_row4_col1" class="data row4 col1" >9923</td>
#       <td id="T_2d4a7_row4_col2" class="data row4 col2" >-0.0062</td>
#       <td id="T_2d4a7_row4_col3" class="data row4 col3" >0.0062</td>
#       <td id="T_2d4a7_row4_col4" class="data row4 col4" >negative</td>
#       <td id="T_2d4a7_row4_col5" class="data row4 col5" >16.7675</td>
#       <td id="T_2d4a7_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_2d4a7_row4_col7" class="data row4 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row5" class="row_heading level0 row5" >224</th>
#       <td id="T_2d4a7_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_2d4a7_row5_col1" class="data row5 col1" >16579</td>
#       <td id="T_2d4a7_row5_col2" class="data row5 col2" >0.0047</td>
#       <td id="T_2d4a7_row5_col3" class="data row5 col3" >0.0047</td>
#       <td id="T_2d4a7_row5_col4" class="data row5 col4" >positive</td>
#       <td id="T_2d4a7_row5_col5" class="data row5 col5" >0.5563</td>
#       <td id="T_2d4a7_row5_col6" class="data row5 col6" >1.0000</td>
#       <td id="T_2d4a7_row5_col7" class="data row5 col7" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2d4a7_level0_row6" class="row_heading level0 row6" >225</th>
#       <td id="T_2

# %%
results.columns
# Out:
# Index(['corpus', 'layer', 'n_words', 'n_sae_features_available', 'n_sae_features_selected_final', 'n_sae_features_selected_stable_60pct',
#        'heldout_r2_controls', 'heldout_r2_controls_surprisal', 'heldout_r2_controls_sae', 'heldout_r2_combined',
#        'heldout_delta_r2_surprisal', 'heldout_delta_r2_sae_over_surprisal', 'heldout_delta_r2_sae_over_controls', 'lasso_alpha_sae_mean',
#        'lasso_alpha_combined_mean', 'lasso_alpha_combined_final', 'r_l0_rt', 'p_l0_rt', 'controls_ci_low', 'controls_ci_high',
#        'controls_surprisal_ci_low', 'controls_surprisal_ci_high', 'controls_sae_ci_low', 'controls_sae_ci_high', 'combined_ci_low',
#        'combined_ci_high', 'delta_surprisal_ci_low', 'delta_surprisal_ci_high', 'delta_sae_over_surprisal_ci_low',
#        'delta_sae_over_surprisal_ci_high', 'delta_sae_over_controls_ci_low', 'delta_sae_over_controls_ci_high', 'dataset'],
#       dtype='str')

# %%
results['selection_rate'] = (
    results['n_sae_features_selected_stable_60pct'] / results['n_sae_features_available']
)

# %%
selection_rate = (
    results.groupby('layer')  # Group by layer
    .agg(selection_rate=('selection_rate', 'mean'))  # Calculate mean selection rate
    .reset_index()
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pivot table: rows = dataset, columns = layers, values = selection_rate
heatmap_data = results.pivot_table(
    index='dataset',  # Replace with another column if needed
    columns='layer',
    values='selection_rate',
    aggfunc='mean'
)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(
    heatmap_data,
    cmap='YlGnBu',
    annot=True,
    fmt='.2f',
    cbar_kws={'label': 'Selection Rate'}
)
plt.title('Feature Selection Rate by Layer')
plt.xlabel('Layer')
plt.ylabel('Dataset')
plt.show()

# %%
# Group by layer (features) and corpus (words) to calculate raw counts
feature_word_counts = (
    results.groupby(['layer', 'corpus'])  # Replace 'corpus' with another column if needed
    .agg(raw_count=('n_sae_features_selected_stable_60pct', 'sum'))  # Sum raw counts
    .reset_index()
)

# %%
# Pivot table: rows = features (layers), columns = words (corpus), values = raw counts
heatmap_data = feature_word_counts.pivot_table(
    index='layer',  # Features
    columns='corpus',  # Words
    values='raw_count',
    fill_value=0  # Fill missing values with 0
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(
    heatmap_data,
    cmap='YlGnBu',
    annot=True,  # Optional: show raw counts in cells
    fmt='d',  # Integer formatting for raw counts
    cbar_kws={'label': 'Raw Count'}
)
plt.title('Raw Counts of Stable Features Selected by Layer and Corpus')
plt.xlabel('Corpus (Words)')
plt.ylabel('Layer (Features)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 6
#       2 import matplotlib.pyplot as plt
#       3
#       4 # Plot heatmap
#       5 plt.figure(figsize=(12, 6))
# ----> 6 sns.heatmap(
#       7     heatmap_data,
#       8     cmap='YlGnBu',
#       9     annot=True,  # Optional: show raw counts in cells
#
# File ~/miniconda3/envs/saert/lib/python3.11/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~/miniconda3/envs/saert/lib/python3.11/site-packages/seaborn/matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File ~/miniconda3/envs/saert/lib/python3.11/site-packages/seaborn/matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
heatmap_data_normalized = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# %%
sns.heatmap(
    heatmap_data_normalized,
    cmap='YlGnBu',
    annot=True,
    fmt='.2f',  # float for percentages
    cbar_kws={'label': 'Proportion'}
)
# Out:
# <Axes: xlabel='corpus', ylabel='layer'>
